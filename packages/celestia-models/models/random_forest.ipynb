# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('../data/large_skill_injector_domain.csv')

# %%
data.head()
# Out:
#        average        date    highest       lowest  order_count  volume
# 0  797900000.0  2022-07-01  804300000  793000000.0          182     217
# 1  797700000.0  2022-07-02  805450000  790000000.0          110     139
# 2  809600000.0  2022-07-03  818750000  800500000.0           98     110
# 3  824200000.0  2022-07-04  825000000  819200000.0          103     127
# 4  829700000.0  2022-07-05  833500000  826500000.0          103     132

# %%
# Change the index to the date column since we are doing time series predictions
data = data.set_index('date')

# %%
# Plot out each of our values to try and find a stable one to predict decided on average
data.plot.line(y="average", use_index=True)
# data.plot.line(y="lowest", use_index=True)
# data.plot.line(y="highest", use_index=True)
# Out:
# <Axes: xlabel='date'>

# %%
# Create our tomrrow column from our historic data
data["tomorrow"] = data["average"].shift(-1)

# %%
# Create our target column for our ML that just determines if the average will increase or decrease
data["target"] = (data["tomorrow"] > data["average"]).astype(int)

# %%
# Default model
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = data.iloc[:-100]
test = data.iloc[-100:]

predictors = ["average", "highest", "lowest", "order_count", "volume"]
model.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

# Get our predictions
preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)

# %%
# Score our model
precision_score(test["target"], preds)
# Out:
# 0.5964912280701754

# %%
# Plot our predictions
combined = pd.concat([test["target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# Start of initial backtest
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="predictions")
    combined = pd.concat([test["target"], preds], axis=1)
    return combined

# %%
def backtest(data,model, predictors, start=100, step=2):
    all_predictions = []

    for i in range(start, data.shape[0], step):
      train = data.iloc[0:i].copy()
      test = data.iloc[i:(i+step)].copy()
      predictions = predict(train, test, predictors, model)
      all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(data, model, predictors)

# %%
predictions["predictions"].value_counts()
# Out:
# predictions
# 0    159
# 1    153
# Name: count, dtype: int64

# %%
precision_score(predictions["target"], predictions["predictions"])
# Out:
# 0.6013071895424836

# %%
predictions["target"].value_counts() / predictions.shape[0]
# Out:
# target
# 1    0.525641
# 0    0.474359
# Name: count, dtype: float64

# %%
# Adding horizons to the data to help with predictions
horizons = [2,7,14]
new_predictors = []

for horizon in horizons:
    rolling_averages = data.rolling(horizon).mean()

    ratio_column = f"close_ratio_{horizon}"
    data[ratio_column] = data['average'] / rolling_averages['average']

    trend_column = f"trend_{horizon}"
    data[trend_column] = data.shift(1).rolling(horizon).sum()["target"]

    new_predictors += [ratio_column, trend_column]

# %%
data
# Out:
#                  average    highest       lowest  order_count  volume  \
# date
# 2022-07-01  7.979000e+08  804300000  793000000.0          182     217
# 2022-07-02  7.977000e+08  805450000  790000000.0          110     139
# 2022-07-03  8.096000e+08  818750000  800500000.0           98     110
# 2022-07-04  8.242000e+08  825000000  819200000.0          103     127
# 2022-07-05  8.297000e+08  833500000  826500000.0          103     132
# ...                  ...        ...          ...          ...     ...
# 2023-08-12  9.129000e+08  914900000  895000000.0          134     208
# 2023-08-13  9.168000e+08  918500000  911900000.0           92     134
# 2023-08-14  9.062789e+08  919900000  899800000.0           60      71
# 2023-08-15  9.107562e+08  931100000  835500000.0           48      64
# 2023-08-16  9.014243e+08  911900000  834700000.0           57      74
#
#                 tomorrow  target  close_ratio_2  trend_2  close_ratio_7  \
# date
# 2022-07-01  7.977000e+08       0            NaN      NaN            NaN
# 2022-07-02  8.096000e+08       1       0.999875      NaN            NaN
# 2022-07-03  8.242000e+08       1       1.007404      1.0            NaN
# 2022-07-04  8.297000e+08       1       1.008936      2.0            NaN
# 2022-07-05  8.135000e+08       0       1.003325      2.0            NaN
# ...                  ...     ...            ...      ...            ...
# 2023-08-12  9.168000e+08       1       1.007116      2.0       1.011356
# 2023-08-13  9.062789e+08       0       1.002131      2.0       1.014184
# 2023-08-14  9.107562e+08       1       0.994229      1.0       1.002802
# 2023-08-15  9.014243e+08       0       1.002464      1.0       1.007222
# 2023-08-16           NaN       0       0.994850      1.0       0.996599
#
#             trend_7  close_ratio_14  trend_14
# date
# 2022-07-01      NaN             NaN       NaN
# 2022-07-02      NaN             NaN       NaN
# 2022-07-03      NaN             NaN       NaN
# 2022-07-04      NaN             NaN       NaN
# 2022-07-05      NaN             NaN       NaN
# ...             ...             ...       ...
# 2023-08-12      3.0        1.007919       7.0
# 2023-08-13      4.0        1.011787       7.0
# 2023-08-14      3.0        1.000599       6.0
# 2023-08-15      4.0        1.005665       6.0
# 2023-08-16      4.0        0.995877       6.0
#
# [412 rows x 13 columns]

# %%
# Start of model that predicts the probabilities
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= .6] = 1
    preds[preds< .6] = 0
    preds = pd.Series(preds, index=test.index, name="predictions")
    combined = pd.concat([test["target"], preds], axis=1)
    return combined

# %%
data = data.dropna()
data
# Out:
#                  average    highest       lowest  order_count  volume  \
# date
# 2022-07-15  8.199000e+08  825000000  751700000.0          160     221
# 2022-07-16  8.212000e+08  827300000  815000000.0           95     139
# 2022-07-17  8.218000e+08  826700000  819900000.0          138     191
# 2022-07-18  8.274000e+08  835900000  825000000.0           78     114
# 2022-07-19  8.266000e+08  827300000  758500000.0           89     127
# ...                  ...        ...          ...          ...     ...
# 2023-08-11  9.000000e+08  906150000  887700000.0          158     203
# 2023-08-12  9.129000e+08  914900000  895000000.0          134     208
# 2023-08-13  9.168000e+08  918500000  911900000.0           92     134
# 2023-08-14  9.062789e+08  919900000  899800000.0           60      71
# 2023-08-15  9.107562e+08  931100000  835500000.0           48      64
#
#                 tomorrow  target  close_ratio_2  trend_2  close_ratio_7  \
# date
# 2022-07-15  8.212000e+08       1       0.999025      1.0       1.017658
# 2022-07-16  8.218000e+08       1       1.000792      1.0       1.016353
# 2022-07-17  8.274000e+08       1       1.000365      2.0       1.004389
# 2022-07-18  8.266000e+08       0       1.003396      2.0       1.008873
# 2022-07-19  8.186000e+08       0       0.999516      1.0       1.006626
# ...                  ...     ...            ...      ...            ...
# 2023-08-11  9.129000e+08       1       1.009339      1.0       0.997649
# 2023-08-12  9.168000e+08       1       1.007116      2.0       1.011356
# 2023-08-13  9.062789e+08       0       1.002131      2.0       1.014184
# 2023-08-14  9.107562e+08       1       0.994229      1.0       1.002802
# 2023-08-15  9.014243e+08       0       1.002464      1.0       1.007222
#
#             trend_7  close_ratio_14  trend_14
# date
# 2022-07-15      4.0        1.015541       7.0
# 2022-07-16      4.0        1.015041       8.0
# 2022-07-17      5.0        1.014689       8.0
# 2022-07-18      5.0        1.021316       8.0
# 2022-07-19      4.0        1.020607       7.0
# ...             ...             ...       ...
# 2023-08-11      3.0        0.995572       6.0
# 2023-08-12      3.0        1.007919       7.0
# 2023-08-13      4.0        1.011787       7.0
# 2023-08-14      3.0        1.000599       6.0
# 2023-08-15      4.0        1.005665       6.0
#
# [397 rows x 13 columns]

# %%
predictions = backtest(data, model, new_predictors)

# %%
predictions["predictions"].value_counts()
# Out:
# predictions
# 0.0    198
# 1.0     99
# Name: count, dtype: int64

# %%
precision_score(predictions["target"], predictions["predictions"])
# Out:
# 0.5858585858585859
